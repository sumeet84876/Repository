# %% [markdown]
# **Files, exceptional handling, logging and memory management Questions**
#
#
# 1. what is Difference between interpreted and compiled languages?
#
#   =>Interpreted: Code is executed line-by-line by an interpreter (e.g., Python, JavaScript). Slower but easier to debug.Compiled: Code is converted into machine code by a compiler before execution. Faster but needs recompilation after changes.
#
# 2. what is Exception handling in Python?
#
#   =>Mechanism to handle runtime errors gracefully without stopping the program. Uses try, except, else, and finally blocks.
#
# 3. what is Purpose of the finally block in exception handling?
#
#   =>Code inside finally always runs, whether an exception occurs or not. Often used for cleanup tasks (closing files, releasing resources).
#
# 4. what Logging in Python?
#
#   =>A built-in module (logging) to record events, errors, and other runtime information for debugging or monitoring.
#
# 5. what is Significance of the __del__ method?
#
#   =>Destructor method called when an object is about to be destroyed; used for cleanup (but not always reliable for critical cleanup).
#
# 6. what is Difference between import and from ... import i python?
#
#   =>import module → imports the whole module.
#
#   =>from module import name → imports specific attributes/functions from the module.
#
# 7. How can you Handling multiple exceptions?
#
#   =>Use multiple except blocks or a single except with a tuple:
#
#
# 8. what is Purpose of with statement when handling files in python?
#
#   =?Ensures the file is automatically closed after its block ends, even if errors occur.
#
#  ex - with open("file.txt") as f:
#       data = f.read()
#
#
# 9. what is Difference between multithreading and multiprocessing?
#
#   =>Multithreading: Multiple threads share the same memory space, lightweight, good for I/O-bound tasks.
#
#   =>Multiprocessing: Multiple processes have separate memory, good for CPU-bound tasks.
#
# 10. what are Advantages of using logging in program?
#
#   =>Keeps records of program execution, helps debug, allows monitoring, can be directed to files/servers.
#
# 11. what is Memory management in Python?
#
#   =>Python uses automatic memory management with a private heap and garbage collector.
#
# 12. what are Basic steps envolved in exception handling in python?
#
#   =>try → Code that may raise an exception.
#
#   =>except → Handle the exception.
#
#   =>else → Run if no exception occurs.
#
#   =>finally → Always runs for cleanup.
#
# 13. Why is memory management is important in python?
#
#   =>Prevents memory leaks, optimizes performance, and ensures program stability.
#
# 14. what is Role of try and except in exception handling?
#
#   =>try: Contains risky code.
#
#   =>except: Defines how to handle specific errors.
#
# 15. How does Python's garbage collection system works?
#
#   =>Uses reference counting and a cyclic garbage collector to remove unused objects.
#
# 16. what is Purpose of the else block in exception handling?
#
#   =>Runs only if no exception is raised in the try block.
#
# 17. what are the Common logging levels in Python?
#
#   =>DEBUG, INFO, WARNING, ERROR, CRITICAL.
#
# 18. what is Difference between os.fork() and multiprocessing in python?
#
#   =>os.fork() (Unix only): Low-level system call to create a new process.
#
#   =>multiprocessing: Cross-platform high-level API for process creation.
#
# 19. what is the Importance of closing a file in python?
#
#   =>Frees system resources, ensures data is saved properly.
#
# 20. what is Difference between file.read() and file.readline()?
#
#   =>read() → Reads entire file or given number of characters.
#
#   =>readline() → Reads one line at a time.
#
# 21. what is the Logging module in Python used for?
#
#   =>Used for creating logs with timestamps, levels, and messages to track application events.
#
# 22. What is the os module in Python used for in file handling?
#
#   =>Provides functions to interact with the operating system (create, remove, rename files/directories).
#
# 23. What are the challenges associated with memory management in Python?
#
#   =>Cyclic references, memory fragmentation, unpredictable __del__ execution.
#
# 24. How do you raise an exception manually in Python?
#
#   =>raise ValueError("Custom error message")
#
#
# 25. Why is it important to use multithreading in certain applications?
#
#   =>Useful for I/O-bound tasks like file reading, network calls, or UI responsiveness without blocking execution.

# %% [markdown]
# **Practical Questions**

# %% [markdown]
# 1. F How can you open a file for writing in Python and write a string to it?

# %%
file = open("file.txt","w")
file.write("this is my first file")
file.close()

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line?

# %%
file = open("content.txt","w")
file.write("Hello my name is sumeet")
file.write("I am data analytic student")
file.close()
f = open("content.txt","r")
f.seek(0)
print(f.readlines())
# Out:
# ['Hello my name is sumeetI am data analytic student']

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    open("sahil.txt","r")
except Exception as e:
    print(e)
    print("hello")
    print("this is my next step")
# Out:
# [Errno 2] No such file or directory: 'sahil.txt'
# hello
# this is my next step

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file?

# %%
with open("file.txt","r") as destination:
  content = destination.read()

with open("file2.txt","w") as source:
  source.write(content)

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %%
try:
  10/0
except ZeroDivisionError as e:
  print("Not possible due to ",e)
# Out:
# Not possible due to  division by zero

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs

# %%
import logging
try:
  10/0
except ZeroDivisionError as e:
  logging.basicConfig(filename= "error.log",level=logging.ERROR, format="%(asctime)s %(levelname)s %(message)s")
  logging.error("This is >> ZeroDivisionError")
# Out:
# ERROR:root:This is >> ZeroDivisionError

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

# %%
import logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='app.log',
    filemode='w'
)
logging.debug("This is a DEBUG message")
logging.info("This is an INFO message")
logging.warning("This is a WARNING message")
logging.error("This is an ERROR message")
logging.critical("This is a CRITICAL message")
# Out:
# WARNING:root:This is a WARNING message
# ERROR:root:This is an ERROR message
# CRITICAL:root:This is a CRITICAL message

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling?

# %%
try:
  open("file2.txt","r")
except FileNotFoundError as e:
  print("This is file not foun error",e)
# Out:
# This is file not foun error [Errno 2] No such file or directory: 'file2.txt'

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?

# %%
with open("file.txt","r") as file:
  l=[]
  for data in file:
    l.append(data)
print(l)
# Out:
# ['this is my first file']

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
with open("content.txt","a") as file:
  file.write("from pwskills")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist?

# %%
dirictory = {"a":1,"b":2}
try:
  dirictory["c"]

except KeyError as e:
  print("This is KeyError",e)
# Out:
# This is KeyError 'c'

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

# %%
try:
  4/0
  10/"2"
  int("abc")
except ZeroDivisionError as e:
  print("This is zeroDivisionError",e)
except TypeError as t:
  print("This is TypeError",t)
except ValueError as v:
  print("This is ValueError",v)

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os
if os.path.exists("/content/file.txt"):
  with open("/content/file.txt","r") as file:
    lines = file.readlines()
  print(lines)

else:
  print("file not found")
# Out:
# ['this is my first file']

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages?

# %%
import logging

logging.basicConfig(filename="example.log", level=logging.DEBUG,format = "%(asctime)s %(levelname)s %(message)s",force=True)
logging.debug("this is debug message")
logging.info("this is info message")
logging.shutdown()

with open('example.log', 'r') as f:
    print(f.read())
# Out:
# hello2025-08-14 01:59:23,646 DEBUG this is debug message
# 2025-08-14 01:59:23,646 INFO this is info message

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty?

# %%
with open("file.txt","r") as f:
  if f == "":
    print("file is empty")
  else:
    print(f.read())
# Out:
# this is my first file

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program?

# %%
import tracemalloc

def my_func():
    a = [i for i in range(100000)]
    b = [i*i for i in range(100000)]
    return a, b

tracemalloc.start()

my_func()

current, peak = tracemalloc.get_traced_memory()
print(f"Current memory usage: {current / 10**6} MB")
print(f"Peak memory usage: {peak / 10**6} MB")

tracemalloc.stop()
# Out:
# Current memory usage: 0.000992 MB
# Peak memory usage: 7.994278 MB

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line?

# %%
l = [1,2,3,4,5]
with open("number.txt","w") as f:
    for num in l:
      f.write(str(num) + "\n")

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)
logger.info("This is a test log message.")

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block?

# %%
d = {"a":1, "b":2, "c":3}
l = [1,2,3,4,5]
try:
  d["d"]
except KeyError as k:
  print("This is key error",k)

try:
  l[6]
except IndexError as i:
  print("this is index error",i)
# Out:
# This is key error 'd'
# this is index error list index out of range

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?

# %%
with open("file.txt","r") as f:
  print(f.read())
# Out:
# this is my first file

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word?

# %%
word = "Hello"
with open("content.txt","r") as f:
  content = f.readline()
  print(content.count(word))
# Out:
# 2

# %% [markdown]
# 22.  How can you check if a file is empty before attempting to read its contents?

# %%
with open ("file.txt","r") as f:
  content = f.read()
  if content == "":
    print("file is empty")
  else:
    print("file is not empty")
# Out:
# file is not empty

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling?

# %%
import logging
logging.basicConfig(filename ="error.log", level=logging.ERROR, format="%(asctime)s %(levelname)s %(message)s",force=True)
try:
  with open("data.txt","r") as f:
    f.read()
except FileNotFoundError as e:
  logging.error("this is FileNotFoundError",exc_info=True)
